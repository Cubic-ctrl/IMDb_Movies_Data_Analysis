# %% [markdown]
# # IMDB MOVIES DATA ANALYSIS

# %%
# Importing required modules
import pandas as pd
import numpy as np

# %%
# Load the data
#The dataset can be obtained on Kaggle. 

df = pd.read_csv("IMDB_Movie_Data.csv", index_col ='Title' )
df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
#shape of the data
df.shape
# Out:
# (1000, 11)

# %%
#finding number of classes
df.value_counts()
# Out:
# Rank  Genre                    Description                                                                                                                                                                               Director              Actors                                                                    Year  Runtime (Minutes)  Rating  Votes   Revenue (Millions)  Metascore
# 1     Action,Adventure,Sci-Fi  A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.                                                           James Gunn            Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana                      2014  121                8.1     757074  333.13              76.0         1
# ...

# %%
#Display data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
#Check the columns of the data
df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#Rename the columns for analysis
df.rename(columns={ 'Runtime (Minutes)': 'Runtime', 'Revenue (Millions)': 'Revenue'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
#lowecase the columns using list like object

# %%
df.columns = ['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime', 
                      'rating', 'votes', 'revenue', 'metascore']

# %%
df.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue', 'metascore'],
#       dtype='object')

# %% [markdown]
# #### Handle the missing value columns with the proper assumtion.

# %%
df.isnull()
# Out:
#                           rank  genre  description  director  actors   year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# rank             0
# genre            0
# description      0
# director         0
# actors           0
# year             0
# runtime          0
# rating           0
# votes            0
# revenue        128
# metascore       64
# dtype: int64

# %%
# now replace the missing values of revenue column by its mean value using fillna() method
revenue = df['revenue']

# %%
revenue
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: revenue, Length: 1000, dtype: float64

# %%
revenue.fillna(revenue.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# rank            0
# genre           0
# description     0
# director        0
# actors          0
# year            0
# runtime         0
# rating          0
# votes           0
# revenue         0
# metascore      64
# dtype: int64

# %%
df.describe()
# Out:
#               rank         year      runtime       rating         votes  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000   113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962    18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000    66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000   100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000   111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000   123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000   191.000000     9.000000  1.791916e+06
#
#            revenue   metascore
# count  1000.000000  936.000000
# mean     82.956376   58.985043
# std      96.412043   17.194757
# min       0.000000   11.000000
# 25%      17.442500   47.000000
# 50%      60.375000   59.500000
# 75%      99.177500   72.000000
# max     936.630000  100.000000

# %%
#Desccribe data by genre
df['genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: genre, dtype: object

# %%
df['genre'].value_counts().head(n=30)
# Out:
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Comedy,Drama                  27
# Action,Adventure,Fantasy      27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Crime,Drama,Mystery           23
# Action,Adventure,Drama        18
# Action,Crime,Drama            17
# Horror,Thriller               16
# Drama,Thriller                15
# Biography,Drama,History       14
# Adventure,Family,Fantasy      14
# Biography,Drama               14
# Action,Adventure,Comedy       14
# Action,Crime,Thriller         12
# Action,Comedy,Crime           12
# Horror                        11
# Action,Adventure,Thriller     11
# Crime,Drama                   10
# Animation,Action,Adventure     9
# Action,Thriller                9
# Thriller                       9
# Horror,Mystery,Thriller        9
# ...

# %% [markdown]
# #### Generate the relationship between each continuous variable using corr() method.

# %%
# to know the positive and negative relationship between the columns we can use 'corr' method which gives the details 
# about the correlation between the columns in dataframe object
df.corr()
# Out:
#                rank      year   runtime    rating     votes   revenue  \
# rank       1.000000 -0.261605 -0.221739 -0.219555 -0.283876 -0.252996
# year      -0.261605  1.000000 -0.164900 -0.211219 -0.411904 -0.117562
# runtime   -0.221739 -0.164900  1.000000  0.392214  0.407062  0.247834
# rating    -0.219555 -0.211219  0.392214  1.000000  0.511537  0.189527
# votes     -0.283876 -0.411904  0.407062  0.511537  1.000000  0.607941
# revenue   -0.252996 -0.117562  0.247834  0.189527  0.607941  1.000000
# metascore -0.191869 -0.079305  0.211978  0.631897  0.325684  0.133328
#
#            metascore
# rank       -0.191869
# year       -0.079305
# runtime     0.211978
# rating      0.631897
# votes       0.325684
# revenue     0.133328
# metascore   1.000000

# %%
type(df['genre'])
# Out:
# pandas.core.series.Series

# %%
type(df[['genre']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Find the movies directed by  'Mel Gibson' & 'James Gunn' with the rating greater than or equal to 7.5.

# %%
director_display = (df['director'] == "Mel Gibson") & (df['rating'] >= 8.0)
#director_display.head()

# %%
df[director_display]
# Out:
#                rank                    genre  \
# Title
# Hacksaw Ridge    17  Biography,Drama,History
#
#                                                      description    director  \
# Title
# Hacksaw Ridge  WWII American Army Medic Desmond T. Doss, who ...  Mel Gibson
#
#                                                           actors  year  \
# Title
# Hacksaw Ridge  Andrew Garfield, Sam Worthington, Luke Bracey,...  2016
#
#                runtime  rating   votes  revenue  metascore
# Title
# Hacksaw Ridge      139     8.2  211760    67.12       71.0

# %%
director_display2 = (df['director'] == "James Gunn") & (df['rating'] >= 8.0)

# %%
df[director_display2]
# Out:
#                          rank                    genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
#
#                            director  \
# Title
# Guardians of the Galaxy  James Gunn
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
#
#                          year  runtime  rating   votes  revenue  metascore
# Title
# Guardians of the Galaxy  2014      121     8.1  757074   333.13       76.0

# %% [markdown]
# #### Display all the movies directed by 'M. Night Shyamalan'.

# %%
# display only the films directed by the 'M. Night Shyamalan'
df[df['director'] == "M. Night Shyamalan"]
# Out:
#                     rank                    genre  \
# Title
# Split                  3          Horror,Thriller
# The Visit            319   Comedy,Horror,Thriller
# The Happening        513          Sci-Fi,Thriller
# The Last Airbender   582  Action,Adventure,Family
# Lady in the Water    774    Drama,Fantasy,Mystery
# After Earth          949  Action,Adventure,Sci-Fi
#
#                                                           description  \
# Title
# Split               Three girls are kidnapped by a man with a diag...
# The Visit           Two siblings become increasingly frightened by...
# The Happening       A science teacher, his wife, and a young girl ...
# The Last Airbender  Follows the adventures of Aang, a young succes...
# Lady in the Water   Apartment building superintendent Cleveland He...
# After Earth         A crash landing leaves Kitai Raige and his fat...
#
#                               director  \
# Title
# Split               M. Night Shyamalan
# ...

# %%
type(df[df['rating'] >= 8.0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Display all the director's who got the rating >= 5 for their movies.

# %%
# Display all films with 'rating' greater than or equal to 5
df[df['rating'] >= 5.0]
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
# top director with highest films having 'rating' greater than or equal to 8
#also the total number of the films
df['director'][df['rating'] >= 8.0].value_counts()
# Out:
# Christopher Nolan    5
# Denis Villeneuve     3
# Martin Scorsese      3
# Quentin Tarantino    2
# J.J. Abrams          2
#                     ..
# Byron Howard         1
# Sean Penn            1
# Tom McCarthy         1
# Amber Tamblyn        1
# Bryan Singer         1
# Name: director, Length: 65, dtype: int64

# %% [markdown]
# #### Find all the movies directed by 'James Gunn', & 'Ridley Scott'.

# %%
# finding the films directed by either 'James Gunn' or 'Ridley Scott'
director_moviees = (df['director'] == 'James Gunn') | (df['director'] == 'Ridley Scott')

# %%
df[director_moviees].head()
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# The Martian               103    Adventure,Drama,Sci-Fi
# Robin Hood                388    Action,Adventure,Drama
# American Gangster         471     Biography,Crime,Drama
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# The Martian              An astronaut becomes stranded on Mars after hi...
# Robin Hood               In 12th century England, Robin and his band of...
# American Gangster        In 1970s America, a detective works to bring d...
#
#                              director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
# ...

# %% [markdown]
# #### Display all the movies with the ratings between 8 & 9 and also the films with the highest rating.

# %%
# find the highest rating of all the films
df['rating'].max()
# Out:
# 9.0

# %%
#find the lowest rating of all the films
df['rating'].min()
# Out:
# 1.9

# %%
#display director of  films with a rating of 9 and above
df['director'][df['rating'] >= 9.0].value_counts()
# Out:
# Christopher Nolan    1
# Name: director, dtype: int64

# %%
df[df['rating'] == 9.0]
# Out:
#                  rank               genre  \
# Title
# The Dark Knight    55  Action,Crime,Drama
#
#                                                        description  \
# Title
# The Dark Knight  When the menace known as the Joker wreaks havo...
#
#                           director  \
# Title
# The Dark Knight  Christopher Nolan
#
#                                                             actors  year  \
# Title
# The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#                  runtime  rating    votes  revenue  metascore
# Title
# The Dark Knight      152     9.0  1791916   533.32       82.0

# %%
films_data = (df['rating'] >= 8.0) & (df['rating'] <= 9.0)

# %%
df[films_data]
# Out:
#                           rank                       genre  \
# Title
# Guardians of the Galaxy      1     Action,Adventure,Sci-Fi
# La La Land                   7          Comedy,Drama,Music
# Hacksaw Ridge               17     Biography,Drama,History
# Lion                        19             Biography,Drama
# Arrival                     20        Drama,Mystery,Sci-Fi
# ...                        ...                         ...
# El secreto de sus ojos     743       Drama,Mystery,Romance
# PK                         766        Comedy,Drama,Romance
# How to Train Your Dragon   773  Animation,Action,Adventure
# Koe no katachi             862     Animation,Drama,Romance
# Taare Zameen Par           992          Drama,Family,Music
#
#                                                                 description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# La La Land                A jazz pianist falls for an aspiring actress i...
# ...

# %% [markdown]
# #### Find the movies directed by both 'David Ayer' and 'Billy Ray'

# %%
#Display movies by David Ayer and Billy Ray
df[df['director'].isin(['David Ayer', 'Billy Ray'])].head()
# Out:
#                       rank                     genre  \
# Title
# Suicide Squad            5  Action,Adventure,Fantasy
# Fury                   241          Action,Drama,War
# End of Watch           958      Crime,Drama,Thriller
# Secret in Their Eyes   996       Crime,Drama,Mystery
#
#                                                             description  \
# Title
# Suicide Squad         A secret government agency recruits some of th...
# Fury                  A grizzled tank commander makes tough decision...
# End of Watch          Shot documentary-style, this film follows the ...
# Secret in Their Eyes  A tight-knit team of rising investigators, alo...
#
#                         director  \
# Title
# Suicide Squad         David Ayer
# Fury                  David Ayer
# End of Watch          David Ayer
# Secret in Their Eyes   Billy Ray
#
#                                                                  actors  year  \
# Title
# ...

# %% [markdown]
# #### Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 50th percentile in revenue.

# %%
condition = ((df['year'] >= 2006) & (df['year'] <= 2010))
condition2 = (df['rating'] > 8.0) & (df['revenue'] < df['revenue'].quantile(0.5))

# %%
df[condition & condition2]
# Out:
#                         rank                      genre  \
# Title
# The Prestige              65       Drama,Mystery,Sci-Fi
# Into the Wild            198  Adventure,Biography,Drama
# Pan's Labyrinth          231          Drama,Fantasy,War
# There Will Be Blood      300              Drama,History
# 3 Idiots                 431               Comedy,Drama
# The Lives of Others      477             Drama,Thriller
# Incendies                714          Drama,Mystery,War
# El secreto de sus ojos   743      Drama,Mystery,Romance
# Taare Zameen Par         992         Drama,Family,Music
#
#                                                               description  \
# Title
# The Prestige            Two stage magicians engage in competitive one-...
# Into the Wild           After graduating from Emory University, top st...
# Pan's Labyrinth         In the falangist Spain of 1944, the bookish yo...
# There Will Be Blood     A story of family, religion, hatred, oil and m...
# ...

# %% [markdown]
# #### Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 25th percentile in revenue.

# %%
# display movies made between the 25th percentile in revenue
condition3 = (df['rating'] > 8.0) & (df['revenue'] < df['revenue'].quantile(0.25))

# %%
df[condition & condition3]
# Out:
#                      rank               genre  \
# Title
# 3 Idiots              431        Comedy,Drama
# The Lives of Others   477      Drama,Thriller
# Incendies             714   Drama,Mystery,War
# Taare Zameen Par      992  Drama,Family,Music
#
#                                                            description  \
# Title
# 3 Idiots             Two friends are searching for their long lost ...
# The Lives of Others  In 1984 East Berlin, an agent of the secret po...
# Incendies            Twins journey to the Middle East to discover t...
# Taare Zameen Par     An eight-year-old boy is thought to be a lazy ...
#
#                                              director  \
# Title
# 3 Idiots                              Rajkumar Hirani
# The Lives of Others  Florian Henckel von Donnersmarck
# Incendies                            Denis Villeneuve
# Taare Zameen Par                           Aamir Khan
#
# ...

# %% [markdown]
# #### Finally give the feedback for all movies with 'Good' if the movie 'rating' is >= 8 and 'Average' if the movie rating doesn't follow the condition given.

# %%
# finally let's apply the function to rate the movies with 'Good' and 'Average' feedback for the 'rating' > 8 or <8 respectively
# using apply() method
def giv_feedback(x):
    if x >= 8.0:
        return "Good"
    else:
        return "Average"

# %%
df["rating_review"] = df["rating"].apply(giv_feedback)

df.head()
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
df["rating_review"] = df["rating"].apply(giv_feedback)
df.tail()
# Out:
#                         rank                  genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...
